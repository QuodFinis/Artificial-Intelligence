# %% [markdown]
# ## Pandas
#
# ###  You need to download the penguin data using the below link, and do all the processings that I do with the example dataset
# https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# filename = r"penguins_lter.csv"

# %% [markdown]
# absolute path name = absolute directory+ file_ name
# relative path name: the absolute path is omitted
#
# windows: \    drive character C:\Users\ZhaoY\Downloads\defectpredict\download\kamei2012\input
# Unix: /       /c/Users/ZhaoY/Downloads

# %%
filepath = r"C:\Users\ZhaoY\Downloads\defectpredict\download\kamei2012\input\bugzilla.csv"
df = pd.read_csv(filepath)

# %%
df
# Out:
#       transactionid        commitdate  ns  nm  nf   entropy         la  \
# 0                 3  2001/12/12 17:41   1   1   3  0.579380   0.093620
# 1                 7  1999/10/12 12:57   1   1   1  0.000000   0.000000
# 2                 8   2002/5/15 16:55   3   3  52  0.739279   0.183477
# 3                 9   2002/1/21 15:37   1   1   8  0.685328   0.016039
# 4                10  2001/12/19 16:44   2   2  38  0.769776   0.091829
# ...             ...               ...  ..  ..  ..       ...        ...
# 4615          20762   2002/7/26 16:44   1   1   1  0.000000   0.025698
# 4616          20840   2002/11/13 3:29   1   1   2  0.918296   0.005450
# 4617          20936   2005/9/27 12:54   1   1   1  0.000000   0.000000
# 4618          20937   2005/9/27 13:03   1   1   1  0.000000  21.000000
# 4619          20938   2005/9/27 12:54   1   1   1  0.000000   0.000000
#
#              ld          lt  fix  ndev     pd       npt  exp        rexp  \
# ...

# %%
df.shape
# Out:
# (4620, 17)

# %%
len(df)
# Out:
# 4620

# %%
df.columns
# Out:
# Index(['transactionid', 'commitdate', 'ns', 'nm', 'nf', 'entropy', 'la', 'ld',
#        'lt', 'fix', 'ndev', 'pd', 'npt', 'exp', 'rexp', 'sexp', 'bug'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    transactionid        commitdate  ns  nm  nf   entropy        la        ld  \
# 0              3  2001/12/12 17:41   1   1   3  0.579380  0.093620  0.000000
# 1              7  1999/10/12 12:57   1   1   1  0.000000  0.000000  0.000000
# 2              8   2002/5/15 16:55   3   3  52  0.739279  0.183477  0.208913
#
#            lt  fix  ndev     pd       npt  exp    rexp  sexp  bug
# 0  480.666667    1    14    596  0.666667  143  133.50   129    1
# 1  398.000000    1     1      0  1.000000  140  140.00   137    1
# 2  283.519231    0    23  15836  0.750000  984  818.65   978    0

# %%
df.tail(5)
# Out:
#       transactionid       commitdate  ns  nm  nf   entropy         la  \
# 4615          20762  2002/7/26 16:44   1   1   1  0.000000   0.025698
# 4616          20840  2002/11/13 3:29   1   1   2  0.918296   0.005450
# 4617          20936  2005/9/27 12:54   1   1   1  0.000000   0.000000
# 4618          20937  2005/9/27 13:03   1   1   1  0.000000  21.000000
# 4619          20938  2005/9/27 12:54   1   1   1  0.000000   0.000000
#
#              ld     lt  fix  ndev  pd  npt  exp        rexp  sexp  bug
# 4615   0.039106  895.0    1    21   0  1.0  219  190.083333   212    1
# 4616   0.002725  183.5    1    18  21  1.0  355  252.833333   335    1
# 4617   0.000000    2.0    1     2   0  1.0  961  239.861905     3    0
# 4618   0.000000    2.0    1     2   0  1.0  615  464.500000     3    0
# 4619  42.000000    0.0    1     2   0  1.0  613  462.500000     2    0

# %% [markdown]
# <b> Question:
# Read penguins_lter.csv file, then get how many rows and how many columns of this dataset
# Print out column names of this dataset
# print out the last 10 rows of this dataset

# %%
df.ns
# Out:
# 0       1
# 1       1
# 2       3
# 3       1
# 4       2
#        ..
# 4615    1
# 4616    1
# 4617    1
# 4618    1
# 4619    1
# Name: ns, Length: 4620, dtype: int64

# %%
df['ns']   # df[['ns', 'nf', 'entropy']]
# Out:
# 0       1
# 1       1
# 2       3
# 3       1
# 4       2
#        ..
# 4615    1
# 4616    1
# 4617    1
# 4618    1
# 4619    1
# Name: ns, Length: 4620, dtype: int64

# %%
df[['ns', 'nf']]
# Out:
#       ns  nf
# 0      1   3
# 1      1   1
# 2      3  52
# 3      1   8
# 4      2  38
# ...   ..  ..
# 4615   1   1
# 4616   1   2
# 4617   1   1
# 4618   1   1
# 4619   1   1
#
# [4620 rows x 2 columns]

# %%
df.ns[:5]
# Out:
# 0    1
# 1    1
# 2    3
# 3    1
# 4    2
# Name: ns, dtype: int64

# %%
type(df.ns)
# Out:
# pandas.core.series.Series

# %%
df.iloc[1:8]
# Out:
#    ns  nm  nf   entropy        la        ld          lt  fix  ndev     pd  \
# 1   1   1   1  0.000000  0.000000  0.000000  398.000000    1     1      0
# 2   3   3  52  0.739279  0.183477  0.208913  283.519231    0    23  15836
# 3   1   1   8  0.685328  0.016039  0.012880  514.375000    1    21   1281
# 4   2   2  38  0.769776  0.091829  0.072746  366.815789    1    21   6565
# 5   1   1  16  0.760777  0.018308  0.017666  583.750000    1    20   2098
# 6   2   2  33  0.816160  0.095682  0.041833  403.484848    0    21   6840
# 7   2   2  33  0.816160  0.095682  0.041833  403.484848    1    21   6840
#
#         npt  exp    rexp  sexp  bug   new_vol
# 1  1.000000  140  140.00   137    1  0.500000
# 2  0.750000  984  818.65   978    0  0.333333
# 3  1.000000  579  479.25   550    0  0.250000
# 4  0.763158  413  313.25   405    0  0.200000
# 5  0.750000  595  495.25   566    0  0.166667
# 6  0.727273  548  448.25   540    0  0.142857
# 7  0.727273  482  382.25   474    0  0.125000

# %%
df.loc[:6, ['ns', 'nf']]
# Out:
#    ns  nf
# 0   1   3
# 1   1   1
# 2   3  52
# 3   1   8
# 4   2  38
# 5   1  16
# 6   2  33

# %%
df.loc[(df.ns>1) | (df.nf<50), ['ns', 'nf']]    #parenthese   and: &; or: |
# Out:
#       ns  nf
# 0      1   3
# 1      1   1
# 2      3  52
# 3      1   8
# 4      2  38
# ...   ..  ..
# 4615   1   1
# 4616   1   2
# 4617   1   1
# 4618   1   1
# 4619   1   1
#
# [4620 rows x 2 columns]

# %%
df_test = pd.read_csv("penguins_lter.csv")
df_test.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
df_test
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# <b> Question:
#     Print out the columns Species and Stage
#     print out the columns Species and Stage of previous 10 rows
#     print out "Culmen Length (mm)" value bigger than 45

# %%
df_test.loc[df_test['Culmen Length (mm)']>45, ['Culmen Length (mm)', 'Species', 'Stage']]
# Out:
#      Culmen Length (mm)                                    Species  \
# 19                 46.0        Adelie Penguin (Pygoscelis adeliae)
# 73                 45.8        Adelie Penguin (Pygoscelis adeliae)
# 111                45.6        Adelie Penguin (Pygoscelis adeliae)
# 152                46.5  Chinstrap penguin (Pygoscelis antarctica)
# 153                50.0  Chinstrap penguin (Pygoscelis antarctica)
# ..                  ...                                        ...
# 338                47.2          Gentoo penguin (Pygoscelis papua)
# 340                46.8          Gentoo penguin (Pygoscelis papua)
# 341                50.4          Gentoo penguin (Pygoscelis papua)
# 342                45.2          Gentoo penguin (Pygoscelis papua)
# 343                49.9          Gentoo penguin (Pygoscelis papua)
#
#                   Stage
# 19   Adult, 1 Egg Stage
# 73   Adult, 1 Egg Stage
# 111  Adult, 1 Egg Stage
# 152  Adult, 1 Egg Stage
# 153  Adult, 1 Egg Stage
# ...

# %%
df.head(5)
# Out:
#    ns  nm  nf   entropy        la        ld          lt  fix  ndev     pd  \
# 0   1   1   3  0.579380  0.093620  0.000000  480.666667    1    14    596
# 1   1   1   1  0.000000  0.000000  0.000000  398.000000    1     1      0
# 2   3   3  52  0.739279  0.183477  0.208913  283.519231    0    23  15836
# 3   1   1   8  0.685328  0.016039  0.012880  514.375000    1    21   1281
# 4   2   2  38  0.769776  0.091829  0.072746  366.815789    1    21   6565
#
#         npt  exp    rexp  sexp  bug   new_vol
# 0  0.666667  143  133.50   129    1  1.000000
# 1  1.000000  140  140.00   137    1  0.500000
# 2  0.750000  984  818.65   978    0  0.333333
# 3  1.000000  579  479.25   550    0  0.250000
# 4  0.763158  413  313.25   405    0  0.200000

# %%
df.ns.value_counts()    # set: set([2, 3,3, 1, 4]) = {1, 2,3,4}
# Out:
# 1    3920
# 2     620
# 3      75
# 4       5
# Name: ns, dtype: int64

# %%
df.ns.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.ns.nunique()    # set
# Out:
# 4

# %%
len(set(df.ns))
# Out:
# 4

# %%
df.sort_values(['ns', 'nf']).tail(10)
# Out:
#       transactionid       commitdate  ns  nm  nf   entropy         la  \
# 2                 8  2002/5/15 16:55   3   3  52  0.739279   0.183477
# 1358           2531   2006/7/3 17:26   3   8  53  0.891911   0.018678
# 1424           2708   2005/8/9 21:30   3   3  55  0.888466   0.007088
# 1418           2694   2006/7/3 17:42   3   8  57  0.803811   0.000445
# 365             802  2006/6/20 20:44   3   3  61  0.875274   0.012288
# 2371           5403    2006/7/3 4:53   4   5   9  0.952054   0.003873
# 3304           8324  2005/3/29 16:42   4   5  10  0.667047   0.095813
# 2349           5331  2003/1/28 19:03   4   4  11  0.655125   0.112818
# 52              143  2003/1/28 20:39   4   4  21  0.829655  21.000000
# 12               31   2002/8/26 2:16   4   4  63  0.995305   0.000062
#
#                 ld          lt  fix  ndev     pd       npt   exp        rexp  \
# 2         0.208913  283.519231    0    23  15836  0.750000   984  818.650000
# ...

# %%
df.sort_values("ns", ascending=False)
# Out:
#       transactionid        commitdate  ns  nm  nf   entropy         la  \
# 2349           5331   2003/1/28 19:03   4   4  11  0.655125   0.112818
# 52              143   2003/1/28 20:39   4   4  21  0.829655  21.000000
# 2371           5403     2006/7/3 4:53   4   5   9  0.952054   0.003873
# 3304           8324   2005/3/29 16:42   4   5  10  0.667047   0.095813
# 12               31    2002/8/26 2:16   4   4  63  0.995305   0.000062
# ...             ...               ...  ..  ..  ..       ...        ...
# 1715           3628  2005/12/13 16:39   1   1   1  0.000000   0.033426
# 1717           3640   2006/6/19 12:43   1   1   1  0.000000   0.002304
# 1718           3642   2006/5/29 14:11   1   1   1  0.000000   0.076566
# 1720           3647   2006/1/22 15:10   1   1   1  0.000000   0.007282
# 4619          20938   2005/9/27 12:54   1   1   1  0.000000   0.000000
#
#                 ld          lt  fix  ndev    pd       npt   exp        rexp  \
# ...

# %%
df.sort_index()
# Out:
#       transactionid        commitdate  ns  nm  nf   entropy         la  \
# 0                 3  2001/12/12 17:41   1   1   3  0.579380   0.093620
# 1                 7  1999/10/12 12:57   1   1   1  0.000000   0.000000
# 2                 8   2002/5/15 16:55   3   3  52  0.739279   0.183477
# 3                 9   2002/1/21 15:37   1   1   8  0.685328   0.016039
# 4                10  2001/12/19 16:44   2   2  38  0.769776   0.091829
# ...             ...               ...  ..  ..  ..       ...        ...
# 4615          20762   2002/7/26 16:44   1   1   1  0.000000   0.025698
# 4616          20840   2002/11/13 3:29   1   1   2  0.918296   0.005450
# 4617          20936   2005/9/27 12:54   1   1   1  0.000000   0.000000
# 4618          20937   2005/9/27 13:03   1   1   1  0.000000  21.000000
# 4619          20938   2005/9/27 12:54   1   1   1  0.000000   0.000000
#
#              ld          lt  fix  ndev     pd       npt  exp        rexp  \
# ...

# %%
df_test
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %% [markdown]
# <b> Question:
#     print out how many unique values does "Culmen Length (mm)" have? And what are these values?
#     Sort the dataset based on the column "Culmen Length (mm)" and "Culmen Depth (mm)"
#     Plot the histogram distribution of values of  "Culmen Length (mm)"

# %%
df_test.sort_values(["Culmen Length (mm)", "Culmen Depth (mm)"])
# Out:
#     studyName  Sample Number                                    Species  \
# 142   PAL0910            143        Adelie Penguin (Pygoscelis adeliae)
# 98    PAL0809             99        Adelie Penguin (Pygoscelis adeliae)
# 70    PAL0809             71        Adelie Penguin (Pygoscelis adeliae)
# 92    PAL0809             93        Adelie Penguin (Pygoscelis adeliae)
# 8     PAL0708              9        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 321   PAL0910            102          Gentoo penguin (Pygoscelis papua)
# 169   PAL0708             18  Chinstrap penguin (Pygoscelis antarctica)
# 253   PAL0708             34          Gentoo penguin (Pygoscelis papua)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 339   PAL0910            120          Gentoo penguin (Pygoscelis papua)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %% [markdown]
# df.sort_values, df.value_counts(), df.plot.hist()

# %%
df_test["Culmen Length (mm)"].nunique()
# Out:
# 164

# %%
df_test["Culmen Length (mm)"].value_counts()
# Out:
# 41.1    7
# 45.2    6
# 39.6    5
# 50.5    5
# 50.0    5
#        ..
# 35.6    1
# 36.8    1
# 43.1    1
# 38.5    1
# 49.9    1
# Name: Culmen Length (mm), Length: 164, dtype: int64

# %%
df_test["Culmen Length (mm)"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionid  4620 non-null   int64
#  1   commitdate     4620 non-null   object
#  2   ns             4620 non-null   int64
#  3   nm             4620 non-null   int64
#  4   nf             4620 non-null   int64
#  5   entropy        4620 non-null   float64
#  6   la             4620 non-null   float64
#  7   ld             4620 non-null   float64
#  8   lt             4620 non-null   float64
#  9   fix            4620 non-null   int64
#  10  ndev           4620 non-null   int64
#  11  pd             4620 non-null   int64
#  12  npt            4620 non-null   float64
#  13  exp            4620 non-null   int64
#  14  rexp           4620 non-null   float64
#  15  sexp           4620 non-null   int64
#  16  bug            4620 non-null   int64
# ...

# %%
df.describe()
# Out:
#        transactionid           ns           nm           nf      entropy  \
# count    4620.000000  4620.000000  4620.000000  4620.000000  4620.000000
# mean     5819.241558     1.169913     1.220346     2.287662     0.229153
# std      4223.181222     0.424315     0.569805     4.275243     0.371861
# min         3.000000     1.000000     1.000000     1.000000     0.000000
# 25%      2211.750000     1.000000     1.000000     1.000000     0.000000
# 50%      5193.500000     1.000000     1.000000     1.000000     0.000000
# 75%      8804.250000     1.000000     1.000000     2.000000     0.551098
# max     20938.000000     4.000000     8.000000    63.000000     1.000000
#
#                 la            ld           lt          fix         ndev  \
# count  4620.000000   4620.000000  4620.000000  4620.000000  4620.000000
# mean      0.071410      3.113758   591.379777     0.859957    16.424892
# std       0.491756    198.624600   547.895977     0.347070    10.743430
# ...

# %% [markdown]
# <b> Question: Get your dataset info and describe
#     df.info()
#     df.describe()

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
df_test.describe()
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          342.000000         342.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.459584           1.974793
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.225000          15.600000
# 50%        58.000000           44.450000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           342.000000     342.000000         330.000000
# mean            200.915205    4201.754386           8.733382
# std              14.061714     801.954536           0.551770
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.299890
# ...

# %%
df.nlargest?

# %%
df.nlargest(4, "ns")
# Out:
#       ns  nm  nf   entropy         la            ld          lt  fix  ndev  \
# 12     4   4  63  0.995305   0.000062      0.003964  256.253968    1    26
# 52     4   4  21  0.829655  21.000000  13495.000000    0.000000    0    32
# 2349   4   4  11  0.655125   0.112818      0.112288  171.636364    0    26
# 2371   4   5   9  0.952054   0.003873      0.002324  573.777778    1    37
#
#         pd       npt   exp        rexp  sexp  bug   new_vol
# 12    3520  0.603175   363  336.000000   363    0  0.076923
# 52    1507  0.809524   113   81.166667   108    0  0.018868
# 2349   780  0.909091    89   57.166667    84    0  0.000426
# 2371   185  0.666667  1441  932.333333  1440    1  0.000422

# %%
df.nsmallest(10, "ns")
# Out:
#     ns  nm  nf   entropy        la        ld          lt  fix  ndev    pd  \
# 0    1   1   3  0.579380  0.093620  0.000000  480.666667    1    14   596
# 1    1   1   1  0.000000  0.000000  0.000000  398.000000    1     1     0
# 3    1   1   8  0.685328  0.016039  0.012880  514.375000    1    21  1281
# 5    1   1  16  0.760777  0.018308  0.017666  583.750000    1    20  2098
# 19   1   1   1  0.000000  0.025641  0.025641   39.000000    1     6    86
# 53   1   1   1  0.000000  0.017182  0.010309  291.000000    0    14    56
# 58   1   1   1  0.000000  0.003774  0.003774  265.000000    1    13     8
# 60   1   1   1  0.000000  0.054945  0.003663  273.000000    1    13     2
# 61   1   1   1  0.000000  0.181132  0.200000  265.000000    1    13     9
# 62   1   1   1  0.000000  0.003663  0.003663  273.000000    1    13     6
#
#          npt   exp        rexp  sexp  bug   new_vol
# 0   0.666667   143  133.500000   129    1  1.000000
# ...

# %%
df.ns.max()  #sum(), min(), max(), median(), mean()
# Out:
# 4

# %%
df.quantile?

# %%
df.quantile([0.25, 0.50])
# Out:
#       transactionid   ns   nm   nf  entropy        la        ld     lt  fix  \
# 0.25        2211.75  1.0  1.0  1.0      0.0  0.003093  0.001295  210.0  1.0
# 0.50        5193.50  1.0  1.0  1.0      0.0  0.009909  0.005109  455.0  1.0
#
#       ndev    pd  npt    exp   rexp   sexp  bug
# 0.25   7.0   3.0  1.0   58.0   52.0   35.0  0.0
# 0.50  16.0  20.0  1.0  196.0  156.0  129.5  0.0

# %%
values = np.ones(len(df))/np.arange(1, len(df)+1)

# %%
len(values)
# Out:
# 4620

# %%
df["new_col"] = value

# %%
# df.ns

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist?

# %%
df.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['transactionid', 'commitdate', 'ns', 'nm', 'nf', 'entropy', 'la', 'ld',
#        'lt', 'fix', 'ndev', 'pd', 'npt', 'exp', 'rexp', 'sexp', 'bug',
#        'new_vol'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionid  4620 non-null   int64
#  1   commitdate     4620 non-null   object
#  2   ns             4620 non-null   int64
#  3   nm             4620 non-null   int64
#  4   nf             4620 non-null   int64
#  5   entropy        4620 non-null   float64
#  6   la             4620 non-null   float64
#  7   ld             4620 non-null   float64
#  8   lt             4620 non-null   float64
#  9   fix            4620 non-null   int64
#  10  ndev           4620 non-null   int64
#  11  pd             4620 non-null   int64
#  12  npt            4620 non-null   float64
#  13  exp            4620 non-null   int64
#  14  rexp           4620 non-null   float64
#  15  sexp           4620 non-null   int64
#  16  bug            4620 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['transactionid', 'commitdate', 'ns', 'nm', 'nf', 'entropy', 'la', 'ld',
#        'lt', 'fix', 'ndev', 'pd', 'npt', 'exp', 'rexp', 'sexp', 'bug',
#        'new_vol'],
#       dtype='object')

# %%
df = df.drop(["commitdate", "transactionid"], axis = 1)

# %%
for col in df.columns:
    print(col)
    fig, ax = plt.subplots()
    df[col].plot.hist(ax = ax)
    ax.set_xlabel(col)
# Out:
# ns
# nm
# nf
# entropy
# la
# ld
# lt
# fix
# ndev
# pd
# npt
# exp
# rexp
# sexp
# bug
# new_vol

# %%
df.plot.box()   # raw data which needs to do some pre-processing
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = "ns", y="nf")
# Out:
# <AxesSubplot:xlabel='ns', ylabel='nf'>

# %%
import seaborn as sns

# %%
# sns.heatmap(df, annot=True)

# %%
# sns.pairplot(df)

# %%
# df.entropy.plot.line()

# %%
def read_kameidata(input_file_path, timewise):
    filepath = os.path.join(input_file_path, '{}.{}'.format("*", 'csv'))
    filenames = glob.glob(filepath)

    df_dict = {}
    for file in filenames:
        filename = file.split('\\')[-1][:-4]

        df = pd.read_csv(file)

        df = __denormalize(df)

        # df["churn"] = (df.la+df.ld)*df['lt']/2
        # df["density"] = 1/df["churn"]
        df["churn"] = df.la+df.ld

        if timewise:
            df = df.drop(["transactionid"], axis=1)
            df["commitdate"] = pd.to_datetime(df["commitdate"], format='%Y-%m-%d %H:%M')

            df = df.sort_values('commitdate', ascending=True)
            # fileoutput = os.path.join(sorted_dataset, filename + '.' + 'csv')
            # df.to_csv(fileoutput)

        else:
            df = df.drop(["transactionid", "commitdate"], axis=1)

        df_dict[filename] = df

    return df_dict
